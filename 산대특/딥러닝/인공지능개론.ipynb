# %%
from IPython.display import Image

# %%
# 머신러닝의 종류

# %%
Image(url='https://git.io/JtIQ1', width=500)
# Out:
# <img src="https://git.io/JtIQ1" width="500"/>

# %%
Image(url='https://git.io/JtIQH', width=500)
# Out:
# <img src="https://git.io/JtIQH" width="500"/>

# %%
Image(url='https://git.io/JtIQ5', width=300)
# Out:
# <img src="https://git.io/JtIQ5" width="300"/>

# %%
Image(url='https://git.io/JtIQd', width=300)
# Out:
# <img src="https://git.io/JtIQd" width="300"/>

# %%
Image(url='https://git.io/JtIQN', width=300)
# Out:
# <img src="https://git.io/JtIQN" width="300"/>

# %%
Image(url='https://git.io/JtIQx', width=300)
# Out:
# <img src="https://git.io/JtIQx" width="300"/>

# %%
Image(url='https://git.io/JtIQp', width=500)
# Out:
# <img src="https://git.io/JtIQp" width="500"/>

# %%
from sklearn.datasets import load_iris

# %%
# 분류 
# 예측
print(load_iris().DESCR)
# Out:
# .. _iris_dataset:
#
# Iris plants dataset
# --------------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 150 (50 in each of three classes)
#     :Number of Attributes: 4 numeric, predictive attributes and the class
#     :Attribute Information:
#         - sepal length in cm
#         - sepal width in cm
#         - petal length in cm
#         - petal width in cm
#         - class:
#                 - Iris-Setosa
#                 - Iris-Versicolour
#                 - Iris-Virginica
#
#     :Summary Statistics:
#
#     ============== ==== ==== ======= ===== ====================
#                     Min  Max   Mean    SD   Class Correlation
#     ============== ==== ==== ======= ===== ====================
#     sepal length:   4.3  7.9   5.84   0.83    0.7826
#     sepal width:    2.0  4.4   3.05   0.43   -0.4194
#     petal length:   1.0  6.9   3.76   1.76    0.9490  (high!)
#     petal width:    0.1  2.5   1.20   0.76    0.9565  (high!)
# ...

# %%
Image(url='https://git.io/JtI7e', width=500)
# Out:
# <img src="https://git.io/JtI7e" width="500"/>

# %% [markdown]
# $\boldsymbol{X} \in \mathbb{R}^{150\times4}$
#
# $\begin{bmatrix}
# x_1^{(1)} & x_2^{(1)} & x_3^{(1)} & x_4^{(1)} \\
# x_1^{(2)} & x_2^{(2)} & x_3^{(2)} & x_4^{(2)} \\
# \vdots & \vdots & \vdots & \vdots \\
# x_1^{(150)} & x_2^{(150)} & x_3^{(150)} & x_4^{(150)} \\
# \end{bmatrix}$
#
# 벡터 : $\boldsymbol{x}\in\mathbb{R}^{n\times1}$
#
# 행렬 : $\boldsymbol{X}\in\mathbb{R}^{n\times m}$
#
# 샘플(행 벡터): $\boldsymbol{x}^{(i)}=\begin{bmatrix} x_1^{(i)} & x_2^{(i)} & x_3^{(i)} & x_4^{(i)}\end{bmatrix}$
#
# 특성(열 벡터): $\boldsymbol{x}_j=\begin{bmatrix} x_j^{(1)} \\ x_j^{(2)} \\ \vdots \\ x_j^{(150)} \end{bmatrix}$
#
# 타깃(열 벡터): $\boldsymbol{y}=\begin{bmatrix} y^{(1)} \\ y^{(2)} \\ \vdots \\ y^{(150)} \end{bmatrix}$ $(y \in \text{\{Setosa, Versicolor, Virginica\}})$

# %%
# 시각화 (상관계수, 각 컬럼별 2차원평면에 분포형태)
# 분류 : 품종별로
# 특성:4가지특성을 이용해서 예측, 4개중에 한개를 정답으로 보고 3개의 특성을 이용해서 예측

# %% [markdown]
# # 전처리
#     스케일조정
#     차원축소
#     훈련데이터셋과 테스트 데이터셋 분리

# %% [markdown]
# # 모델선택과 훈련
#     모델선택의 기준 : 지도학습 / 비지도학습 / 강화학습
#     지도학습 : 정답이 있으면 -->98%                    --> 강화학습 고려(이미지나, 음성, 특성데이터가 많은경우(특성이 많은경우))
#     비지도학습 : 정답이 없는경우 --> 특이케이스

# %% [markdown]
# # 평가
#     우연에의한 가능성을 배재
#     교차검증
#     혼돈매트릭스 : 사이킷런에서 제공  정확도, 정밀도, 재현율 F1 score
#     가장많이 사용하는 지표는 : 정확도(accuracy) - 때에따라서 신뢰할수 없음  테이터편향이 심한경우... 정상인이 1000명이도 환자가 1명 꼴로 데이터가
#     인공지능이 사실 전부 정상으로 판단하면  정확도  99%

# %% [markdown]
# # 활성함수
#     계단함수 - 시그모이드- 소프트맥스 - 렐루....
#     시그모이드는 이진분류
#     소프트맥스 다중분류
#     렐루 학습의 중간과정에서사용
# # 손실함수
#     회귀 : 평균제곱오차
#     분류 :크로스엔트로피
#             바이너리 크로스엔트로피 -> 이진분류
#             스페어드 세퍼레이트 크로스에트로피 -  정답에해당하는 라벨이 원핫형태가 아닐때.
#             카테고리컬 크로스엔트로피         - 정답에해당하는 라벨이 원핫형태일때.

# %% [markdown]
# # 강화학습 설계
#     순수신경망
#     컨볼류션이 결합된 신경망
#     컨볼류션으로만이우러진 모델 - 기 제공되는 검증된 모델...(ResNet50, VGG16, Rense) 이걸 사용하는걸 전이학습 : 특성분리기로 사용
#     LSTM(장단기 메모리) : 층  - 시계열데이터에서 과거 정보가 중요할때.. 사용을 권장 , 날씨, 주가, 문장(뎃글분석)

# %% [markdown]
# # 순수신경망 - 다층퍼셉트론
#     퍼셉트론 : 하나의 신경망
#         전방계산(forward) - 오차계산 - 역전파(backward)  : torch 로 구현하는 딥러닝은.. 따로 만들거나 일일이 적용해 줘야.. 그래서 클래스
#         def perceptron(nn.Module):
#             __inint__(n_sample) : 가중치 초기화
#         def forward():
#             while():
#                 ....
#                 ,,,
#                 n_input = n_output

# %% [markdown]
# # 순수 신경망에서 층 - Dense
#     은닉층  출력개수, 활성화함수

# %% [markdown]
# # 강화학습은 과적합이 일어나기 쉬운구조
#     규제가 필수  DropOut : 비율

# %% [markdown]
# # 컨볼류션
#     이미지와 같은 파라메터가 괴장히 많은 구조는 신경을 이용하면 overhead가 상당하다
#     주요특성만 추출... 커널,필터라고하는 구조

# %% [markdown]
# ![image.png](attachment:834a0c9f-5cb1-4363-a2ee-688a46df9f8a.png)

# %% [markdown]
# # 설계는 다양하게 가능하지만  과가ㅓ 높은 성능을 보인 ResNet이 설계를 모방해서
#     CCPD CCPD FT FC FC

# %% [markdown]
# # 알고리즘
#     퍼셉트론

# %% [markdown]
# ![image.png](attachment:21ca8e56-ce95-444e-a9b6-13f7654b11d5.png)

# %% [markdown]
# $\boldsymbol{w}=\begin{bmatrix} w_1 \\ \vdots \\ w_m\end{bmatrix}$ ,
# $\boldsymbol{x}=\begin{bmatrix} x_1 \\ \vdots \\ x_m\end{bmatrix}$
#
# 최종 입력(net input) : $z = w_1x_1+w_2x_2+\cdots+w_mx_m$
#
#
# 벡터 점곱(dot product), 행렬 곱셈(matrix multiplication) :
# $\begin{bmatrix}1&2&3\end{bmatrix}\times\begin{bmatrix}4\\5\\6\end{bmatrix}=1\times4+2\times5+3\times6=32$
#
# 점곱을 사용한 표현 : $z = w_1x_1+\cdots+w_mx_m=\sum_{j=1}^mx_jw_j=\boldsymbol{w}^T\boldsymbol{x}$
#
# 퍼셉트론의 결정 함수 : $\phi(z)=\begin{cases}1&z\ge\theta\mbox{ 일 때} \\ -1&\mbox{그 외}\end{cases}$
# $\;\;\;\;\;$
# $\phi(z)=\begin{cases}1&z-\theta\ge0\mbox{ 일 때} \\ -1&\mbox{그 외}\end{cases}$
#
# $w_0=-\theta , x_0=1$ 일 때 : $z_{new} = w_0x_0+w_1x_1+\cdots+w_mx_m=\sum_{j=0}^mx_jw_j=\boldsymbol{w}^T\boldsymbol{x}$

# %% [markdown]
# ![image.png](attachment:0cc58494-bbbc-459b-bee9-4d4f37449abe.png)

# %% [markdown]
# # 퍼셉트론 학습규칙

# %% [markdown]
# $\Delta w_j = \eta(y^{(i)}-\hat{y}^{(i)})x_j^{(i)}$
#
# $w_j := w_j + \Delta w_j$

# %% [markdown]
# # 정답을 예측

# %% [markdown]
# $y^{(i)}=-1,\; \hat{y}^{(i)}=-1, \qquad \Delta w_j=\eta(-1-(-1))x_j^{(i)}=0$
#
# $y^{(i)}=1,\; \hat{y}^{(i)}=1, \qquad \Delta w_j=\eta(1-1)x_j^{(i)}=0$

# %% [markdown]
# # 틀린경우

# %% [markdown]
# $y^{(i)}=1,\;\hat{y}^{(i)}=-1, \qquad \Delta w_j=\eta(1-(-1))x_j^{(i)}=\eta(2)x_j^{(i)}$
#
# $y^{(i)}=-1,\;\hat{y}^{(i)}=1, \qquad \Delta w_j=\eta(-1-1)x_j^{(i)}=\eta(-2)x_j^{(i)}$

# %%
Image(url='https://git.io/JtIbq', width=600)
# Out:
# <img src="https://git.io/JtIbq" width="600"/>

# %%
# 퍼셉트론의 알고리즘
Image(url='https://git.io/JtIbO', width=600)
# Out:
# <img src="https://git.io/JtIbO" width="600"/>

# %% [markdown]
# # 퍼셉트론 API 클래스로 구현

# %%
import numpy as np


class Perceptron(object):
    """퍼셉트론 분류기

    매개변수
    ------------
    eta : float
      학습률 (0.0과 1.0 사이)
    n_iter : int
      훈련 데이터셋 반복 횟수
    random_state : int
      가중치 무작위 초기화를 위한 난수 생성기 시드

    속성
    -----------
    w_ : 1d-array
      학습된 가중치
    errors_ : list
      에포크마다 누적된 분류 오류

    """
    def __init__(self, eta=0.01, n_iter=50, random_state=1):
        self.eta = eta
        self.n_iter = n_iter
        self.random_state = random_state

    def fit(self, X, y):
        """훈련 데이터 학습

        매개변수
        ----------
        X : array-like, shape = [n_samples, n_features]
          n_samples개의 샘플과 n_features개의 특성으로 이루어진 훈련 데이터
        y : array-like, shape = [n_samples]
          타깃값

        반환값
        -------
        self : object

        """
        rgen = np.random.RandomState(self.random_state)
        self.w_ = rgen.normal(loc=0.0, scale=0.01, size=1 + X.shape[1])
        self.errors_ = []

        for _ in range(self.n_iter):
            errors = 0
            for xi, target in zip(X, y):
                update = self.eta * (target - self.predict(xi))
                self.w_[1:] += update * xi
                self.w_[0] += update
                errors += int(update != 0.0)
            self.errors_.append(errors)
        return self

    def net_input(self, X):
        """입력 계산"""
        return np.dot(X, self.w_[1:]) + self.w_[0]

    def predict(self, X):
        """단위 계단 함수를 사용하여 클래스 레이블을 반환합니다"""
        return np.where(self.net_input(X) >= 0.0, 1, -1)

# %%
from sklearn.datasets import load_iris
iris = load_iris()
data = iris.data
target = iris.target

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# 두개의 품종을 선택 'setosa', 'versicolor'
iris.target_names
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype='<U10')

# %%
# 이진 분류  setosa 0  versicolor 1
indexs = (target == 0) | (target == 1)
data2 = data[indexs]
target2 = target[indexs]

# %%
len(data2), len(target2)
# Out:
# (100, 100)

# %%
data2 = data2[:,[0,2]]

# %%
# 분포도를 시각화
plt.scatter(data2[:50,0], data2[:50,1],color = 'red', label='setosa')
plt.scatter(data2[50:,0], data2[50:,1], label='versicolor')
plt.legend()
plt.show()

# %% [markdown]
# # 퍼셉트론 훈련

# %%
p = Perceptron(eta=0.1,n_iter = 10,random_state=1)
p.fit(data2,target2)

plt.plot(range(1,len(p.errors_)+1), p.errors_, marker='o')
plt.ylabel("Number of Updates")
plt.xlabel("Epochs")           
plt.show()

# %%
p.errors_
# Out:
# [51, 51, 50, 50, 50, 50, 50, 50, 50, 50]

# %%
# 경계시각화
from matplotlib.colors import ListedColormap
def plot_decisoin_regions(X,y,classifier,resolution=0.02):
    # 마커와 컬러
    marker = ('s','x','o','^','v')
    colors = ('red','blue','lightgreen','gray','cyan')
    camp = ListedColormap(colors[:len(np.unique(y))])
    
    # 경계를 draw
    x1_min, x1_max =  X[:,0].min() - 1, X[:,0].max() + 1 
    x2_min, x2_max =  X[:,1].min() - 1, X[:,1].max() + 1 
    xx1, xx2 = np.meshgrid( np.arange(x1_min, x1_max, resolution), np.arange(x2_min, x2_max, resolution) )
    Z = classifier.predict(np.array([xx1.ravel(), xx2.ravel()]).T)
    Z = Z.reshape(xx1.shape)
    plt.contourf(xx1,xx2,Z, alpha=0.3, cmap=camp)
    plt.xlim(xx1.min(), xx1.max())
    plt.ylim(xx2.min(), xx2.max())
    # 산점도
    for idx, cl in enumerate(np.unique(y)):
        plt.scatter(x = X[y == cl, 0]
                    ,y = X[y == cl, 1]
                    ,alpha = 0.8
                    ,c = colors[idx]
                    ,marker=marker[idx]
                    ,label = cl
                    # ,edgecolor=None if idx == 1 else 'balck'
                   )

# %%
plot_decisoin_regions(data2,target2,classifier=p)
plt.show()

# %% [markdown]
# # 활성화 함수 - activation 개념이 적용되면서 .. 미분

# %%
Image(url='https://git.io/JtIbn', width=600)
# Out:
# <img src="https://git.io/JtIbn" width="600"/>

# %% [markdown]
# ![image.png](attachment:107130d3-2042-418b-9400-bcf758d67bec.png)
# ![image.png](attachment:fa684b87-d464-4c9a-89d0-5f4fd9715b3c.png)

# %% [markdown]
# #### 목적함수 == 비용함수 == 손실함수

# %% [markdown]
# ![image.png](attachment:4ef104ec-c1af-433d-a8c3-b8ce01d4791a.png)

# %%
import numpy as np


class GradientPerceptron(object):
    """퍼셉트론 분류기

    매개변수
    ------------
    eta : float
      학습률 (0.0과 1.0 사이)
    n_iter : int
      훈련 데이터셋 반복 횟수
    random_state : int
      가중치 무작위 초기화를 위한 난수 생성기 시드

    속성
    -----------
    w_ : 1d-array
      학습된 가중치
    errors_ : list
      에포크마다 누적된 분류 오류

    """
    def __init__(self, eta=0.01, n_iter=50, random_state=1):
        self.eta = eta
        self.n_iter = n_iter
        self.random_state = random_state

    def fit(self, X, y):
        """훈련 데이터 학습

        매개변수
        ----------
        X : array-like, shape = [n_samples, n_features]
          n_samples개의 샘플과 n_features개의 특성으로 이루어진 훈련 데이터
        y : array-like, shape = [n_samples]
          타깃값

        반환값
        -------
        self : object

        """
        rgen = np.random.RandomState(self.random_state)
        self.w_ = rgen.normal(loc=0.0, scale=0.01, size=1 + X.shape[1])
        self.cost_ = []

        for _ in range(self.n_iter):
            net_input = self.net_input(X)            
            # 활성함수 : 항등함수를 사용
            # 로지스틱회귀.... activatino을 시그모이드로 변경
            output = self.activation(net_input)
            errors = (y - output)            
            self.w_[1:] += self.eta * X.T.dot(errors)
            self.w_[0] += self.eta*errors.sum()
            cost = (errors**2).sum() / 2.0
            self.cost_.append(cost)            
        return self

    def net_input(self, X):
        """입력 계산"""
        return np.dot(X, self.w_[1:]) + self.w_[0]

    def activation(self, X):
        '''활성화 계산'''
        return X
    
    def predict(self, X):
        """단위 계단 함수를 사용하여 클래스 레이블을 반환합니다"""
        return np.where(self.activation(self.net_input(X)) >= 0.0, 1, -1)

# %%
fig,ax = plt.subplots(1,2,figsize=(10,4))
model1 = GradientPerceptron(n_iter=10, eta=0.01).fit(data2,target2)
model2 = GradientPerceptron(n_iter=10, eta=0.0001).fit(data2,target2)
ax[0].plot(range(1, len(model1.cost_)+1), np.log10(model1.cost_), marker='o')
ax[0].set_xlabel('Epoch')
ax[0].set_ylabel('Sum_squared_error')
ax[1].plot(range(1, len(model2.cost_)+1), np.log10(model2.cost_), marker='o')
ax[1].set_xlabel('Epoch')
ax[1].set_ylabel('Sum_squared_error')
plt.show()

# %%
Image(url='https://git.io/JtIb4', width=700)
# Out:
# <img src="https://git.io/JtIb4" width="700"/>

# %%
# 스케일 조정
